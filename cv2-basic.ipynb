# %%
import pandas as pd
import numpy as np
from glob import glob
import cv2 
import matplotlib.pylab as plt

# %%
dog_files = glob('/kaggle/input/cat-and-dog/training_set/training_set/dogs/*.jpg')
cat_files = glob('/kaggle/input/cat-and-dog/training_set/training_set/cats/*.jpg')

# %%
img_mpl = plt.imread(cat_files[20])
img_cv2 = cv2.imread(cat_files[20])
img_mpl.shape, img_cv2.shape
# Out:
# ((232, 350, 3), (232, 350, 3))

# %%
img_mpl/255
# Out:
# array([[[0.27843137, 0.2745098 , 0.26666667],
#         [0.2745098 , 0.27058824, 0.2627451 ],
#         [0.25098039, 0.24705882, 0.23921569],
#         ...,
#         [0.63921569, 0.65490196, 0.35294118],
#         [0.64313725, 0.65882353, 0.35686275],
#         [0.63137255, 0.64705882, 0.34509804]],
#
#        [[0.28235294, 0.27843137, 0.27058824],
#         [0.27843137, 0.2745098 , 0.26666667],
#         [0.25098039, 0.24705882, 0.23921569],
#         ...,
#         [0.63529412, 0.65098039, 0.34901961],
#         [0.63921569, 0.65490196, 0.35294118],
#         [0.62745098, 0.64313725, 0.34117647]],
#
#        [[0.28235294, 0.27843137, 0.27058824],
#         [0.27843137, 0.2745098 , 0.26666667],
#         [0.25490196, 0.25098039, 0.24313725],
#         ...,
#         [0.63137255, 0.64705882, 0.34509804],
#         [0.63529412, 0.65098039, 0.34901961],
#         [0.62352941, 0.63921569, 0.3372549 ]],
#
#        ...,
#
#        [[0.21960784, 0.21568627, 0.2       ],
#         [0.22352941, 0.21960784, 0.20392157],
#         [0.21176471, 0.20784314, 0.19215686],
#         ...,
#         [0.26666667, 0.2       , 0.23137255],
#         [0.27843137, 0.21176471, 0.24313725],
#         [0.29411765, 0.22745098, 0.25882353]],
#
#        [[0.21960784, 0.21568627, 0.2       ],
#         [0.21960784, 0.21568627, 0.2       ],
#         [0.20784314, 0.20392157, 0.18823529],
#         ...,
#         [0.2745098 , 0.20784314, 0.23921569],
#         [0.28235294, 0.21568627, 0.24705882],
#         [0.29803922, 0.23137255, 0.2627451 ]],
#
#        [[0.21568627, 0.21176471, 0.19607843],
#         [0.21960784, 0.21568627, 0.2       ],
#         [0.20784314, 0.20392157, 0.18823529],
#         ...,
#         [0.29803922, 0.23137255, 0.2627451 ],
#         [0.30196078, 0.23529412, 0.26666667],
#         [0.29803922, 0.23137255, 0.2627451 ]]])

# %%
pd.Series(img_mpl.flatten()).plot(kind='hist',bins=50,title='Distribution of Pixel Values')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img_mpl)
plt.show()

# %%
img_mpl.shape
# Out:
# (232, 350, 3)

# %%
fig, axs = plt.subplots(1, 3, figsize=(15,5))
axs[0].imshow(img_mpl[:,:,0],cmap='Reds')
axs[1].imshow(img_mpl[:,:,1],cmap='Greens')
axs[2].imshow(img_mpl[:,:,2],cmap='Blues')
axs[0].axis("off")
axs[1].axis("off")
axs[1].axis("off")
axs[0].set_title('Red Channel')
axs[1].set_title('Green Channel')
axs[2].set_title('Blue Channel')
# Out:
# Text(0.5, 1.0, 'Blue Channel')
